# %%
# %load datasets_questions/explore_enron_data.py
#!/usr/bin/python

""" 
    Starter code for exploring the Enron dataset (emails + finances);
    loads up the dataset (pickled dict of dicts).

    The dataset has the form:
    enron_data["LASTNAME FIRSTNAME MIDDLEINITIAL"] = { features_dict }

    {features_dict} is a dictionary of features associated with that person.
    You should explore features_dict as part of the mini-project,
    but here's an example to get you started:

    enron_data["SKILLING JEFFREY K"]["bonus"] = 5600000
    
"""

import pickle

enron_data = pickle.load(open("final_project/final_project_dataset.pkl", "r"))

# %%
from IPython.display import display
import numpy as np
import pandas as pd

data = pd.DataFrame.from_dict(enron_data, orient='index')

display(data)
print data.shape
print data[data['poi'] == True].shape
# Out:
#                                  salary to_messages deferral_payments  \
# ALLEN PHILLIP K                  201955        2902           2869717
# BADUM JAMES P                       NaN         NaN            178980
# BANNANTINE JAMES M                  477         566               NaN
# BAXTER JOHN C                    267102         NaN           1295738
# BAY FRANKLIN R                   239671         NaN            260455
# BAZELIDES PHILIP J                80818         NaN            684694
# BECK SALLY W                     231330        7315               NaN
# BELDEN TIMOTHY N                 213999        7991           2144013
# BELFER ROBERT                       NaN         NaN           -102500
# BERBERIAN DAVID                  216582         NaN               NaN
# BERGSIEKER RICHARD P             187922         383               NaN
# BHATNAGAR SANJAY                    NaN         523               NaN
# ...

# %%
data.loc['PRENTICE JAMES']['total_stock_value']
# Out:
# 1095040

# %%
data.loc['Colwell Wesley'.upper()]['from_this_person_to_poi']
# Out:
# 11

# %%
data.loc['Skilling Jeffrey K'.upper()]['exercised_stock_options']
# Out:
# 19250000

# %%
print data.loc['Skilling Jeffrey K'.upper()]['total_payments']
print data.loc['Lay Kenneth L'.upper()]['total_payments']
# Out:
# 8682716
# 103559793

# %%
len(data[data['salary'] != 'NaN'])
# Out:
# 0.650684931507

# %%
len(data[data['email_address'] != 'NaN'])
# Out:
# 111

# %%
num = len(data[data['total_payments'] == 'NaN'])
print num
print float(num)/146
# Out:
# 21
# 0.143835616438

# %%
num = len(data[(data['total_payments'] == 'NaN') & (data['poi'] == True)])
print num
print float(num)/146
# Out:
# 0
# 0.0
